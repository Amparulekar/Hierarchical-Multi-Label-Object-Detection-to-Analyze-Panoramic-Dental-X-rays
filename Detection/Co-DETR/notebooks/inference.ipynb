# %% [markdown]
# # M1

# %%
import sys
sys.path.append("/raid/infolab/bhavyakohli/mmdet/Co-DETR/")
import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)
warnings.filterwarnings(action='ignore', category=UserWarning)

from mmdet.apis import *

# Setup a checkpoint file to load
checkpoint = '../experiments/quadrant_codetr/latest.pth'
configpath = '../experiments/quadrant_codetr/co_dino_5scale_r50_1x_coco_quadrant.py'

model = init_detector(configpath, checkpoint)
# Out:
# 2024-04-07 21:03:13,294 - mmcv - INFO - initialize RPNHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
# 2024-04-07 21:03:13,309 - mmcv - INFO -
# rpn_conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,310 - mmcv - INFO -
# rpn_conv.bias - torch.Size([256]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,311 - mmcv - INFO -
# rpn_cls.weight - torch.Size([9, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,312 - mmcv - INFO -
# rpn_cls.bias - torch.Size([9]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,312 - mmcv - INFO -
# rpn_reg.weight - torch.Size([36, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,313 - mmcv - INFO -
# rpn_reg.bias - torch.Size([36]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,395 - mmcv - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2024-04-07 21:03:13,585 - mmcv - INFO -
# bbox_head.fc_cls.weight - torch.Size([5, 1024]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,585 - mmcv - INFO -
# bbox_head.fc_cls.bias - torch.Size([5]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,586 - mmcv - INFO -
# bbox_head.fc_reg.weight - torch.Size([16, 1024]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2024-04-07 21:03:13,586 - mmcv - INFO -
# bbox_head.fc_reg.bias - torch.Size([16]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2024-04-07 21:03:13,587 - mmcv - INFO -
# bbox_head.shared_fcs.0.weight - torch.Size([1024, 12544]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-07 21:03:13,587 - mmcv - INFO -
# bbox_head.shared_fcs.0.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-07 21:03:13,588 - mmcv - INFO -
# bbox_head.shared_fcs.1.weight - torch.Size([1024, 1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-07 21:03:13,588 - mmcv - INFO -
# bbox_head.shared_fcs.1.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-07 21:03:13,605 - mmcv - INFO - initialize CoATSSHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01, 'override': {'type': 'Normal', 'name': 'atss_cls', 'std': 0.01, 'bias_prob': 0.01}}
# 2024-04-07 21:03:13,619 - mmcv - INFO -
# cls_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,619 - mmcv - INFO -
# cls_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-07 21:03:13,620 - mmcv - INFO -
# cls_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-07 21:03:13,620 - mmcv - INFO -
# reg_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,621 - mmcv - INFO -
# reg_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-07 21:03:13,621 - mmcv - INFO -
# reg_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-07 21:03:13,621 - mmcv - INFO -
# atss_cls.weight - torch.Size([4, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2024-04-07 21:03:13,622 - mmcv - INFO -
# atss_cls.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2024-04-07 21:03:13,622 - mmcv - INFO -
# atss_reg.weight - torch.Size([4, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,623 - mmcv - INFO -
# atss_reg.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,623 - mmcv - INFO -
# atss_centerness.weight - torch.Size([1, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,623 - mmcv - INFO -
# atss_centerness.bias - torch.Size([1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-07 21:03:13,624 - mmcv - INFO -
# scales.0.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-07 21:03:13,624 - mmcv - INFO -
# scales.1.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-07 21:03:13,625 - mmcv - INFO -
# scales.2.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-07 21:03:13,625 - mmcv - INFO -
# scales.3.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-07 21:03:13,625 - mmcv - INFO -
# scales.4.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-07 21:03:13,626 - mmcv - INFO -
# scales.5.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of CoATSSHead

# %%
imagepath = "/raid/infolab/bhavyakohli/mmdet/Co-DETR/data/dental/test/train_18.png"
results = inference_detector(model, [imagepath] * 1)

# results contains 4 arrays of shape (num_proposals x 5)
# the first 4 elements are the bbox params, last element is the score
# the first entry is the proposal with the highest score

show_result_pyplot(model, imagepath, results[0])

# %%
import cv2

cv2.imread(imagepath).shape
# Out:
# (1504, 2868, 3)

# %%
# Out:
# [array([1459.2903 ,  513.42786, 2381.3794 ,  944.04987], dtype=float32),
#  array([ 597.4335 ,  503.4848 , 1476.835  ,  943.86926], dtype=float32),
#  array([1488.43  ,  817.9161, 2489.5725, 1330.3403], dtype=float32),
#  array([ 522.61035,  828.31836, 1506.689  , 1345.9518 ], dtype=float32)]

# %%
[i.shape for i in results]
# Out:
# [(12, 5), (12, 5), (40, 5), (20, 5)]

# %%
image = cv2.imread(imagepath)
for dic in [i[0][:-1] for i in results[0]]:
    x_min, y_min, width, height = dic
    width = width - x_min
    height = height - y_min

    x_max = x_min + width
    y_max = y_min + height

    # if dic["category_id_1"] == 0:
    #     color = (255, 0, 0)        #red
    # elif dic["category_id_1"] == 1:
    #     color = (0, 255, 0)     #green
    # elif dic["category_id_1"] == 2:
    #     color = (0, 0, 255)     #blue
    # elif dic["category_id_1"] == 3:
    #     color = (0, 0,0)            #black
    thickness = 5
    cv2.rectangle(image, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0,255,0), thickness)
    break

plt.imshow(image)

# %%
[i[0][:-1] for i in results[0]]
# Out:
# [array([1459.2903 ,  513.42786, 2381.3794 ,  944.04987], dtype=float32),
#  array([ 597.4335 ,  503.4848 , 1476.835  ,  943.86926], dtype=float32),
#  array([1488.43  ,  817.9161, 2489.5725, 1330.3403], dtype=float32),
#  array([ 522.61035,  828.31836, 1506.689  , 1345.9518 ], dtype=float32)]

# %%
results[0][0]
# Out:
# array([1.4633262e+03, 5.1041791e+02, 2.3887424e+03, 9.4584613e+02,
#        8.3360791e-01], dtype=float32)

# %% [markdown]
# # M2

# %%
import sys
sys.path.append("/raid/infolab/bhavyakohli/mmdet/Co-DETR/")
import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)
warnings.filterwarnings(action='ignore', category=UserWarning)

from mmdet.apis import *

# Setup a checkpoint file to load
checkpoint = '../experiments/enumeration_codetr_ver2/latest.pth'
configpath = '../experiments/enumeration_codetr_ver2/co_dino_5scale_r50_1x_coco_enumeration.py'

model = init_detector(configpath, checkpoint)
# Out:
# 2024-04-09 21:39:58,868 - mmcv - INFO - initialize RPNHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
# 2024-04-09 21:39:58,910 - mmcv - INFO -
# rpn_conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:39:58,938 - mmcv - INFO -
# rpn_conv.bias - torch.Size([256]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:39:58,939 - mmcv - INFO -
# rpn_cls.weight - torch.Size([9, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:39:58,940 - mmcv - INFO -
# rpn_cls.bias - torch.Size([9]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:39:58,941 - mmcv - INFO -
# rpn_reg.weight - torch.Size([36, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:39:58,943 - mmcv - INFO -
# rpn_reg.bias - torch.Size([36]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:39:59,239 - mmcv - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2024-04-09 21:39:59,863 - mmcv - INFO -
# bbox_head.fc_cls.weight - torch.Size([9, 1024]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:39:59,865 - mmcv - INFO -
# bbox_head.fc_cls.bias - torch.Size([9]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:39:59,866 - mmcv - INFO -
# bbox_head.fc_reg.weight - torch.Size([32, 1024]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2024-04-09 21:39:59,867 - mmcv - INFO -
# bbox_head.fc_reg.bias - torch.Size([32]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2024-04-09 21:39:59,867 - mmcv - INFO -
# bbox_head.shared_fcs.0.weight - torch.Size([1024, 12544]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-09 21:39:59,868 - mmcv - INFO -
# bbox_head.shared_fcs.0.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-09 21:39:59,868 - mmcv - INFO -
# bbox_head.shared_fcs.1.weight - torch.Size([1024, 1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-09 21:39:59,870 - mmcv - INFO -
# bbox_head.shared_fcs.1.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-09 21:39:59,963 - mmcv - INFO - initialize CoATSSHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01, 'override': {'type': 'Normal', 'name': 'atss_cls', 'std': 0.01, 'bias_prob': 0.01}}
# 2024-04-09 21:40:00,056 - mmcv - INFO -
# cls_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:40:00,059 - mmcv - INFO -
# cls_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-09 21:40:00,059 - mmcv - INFO -
# cls_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-09 21:40:00,060 - mmcv - INFO -
# reg_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:40:00,061 - mmcv - INFO -
# reg_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-09 21:40:00,062 - mmcv - INFO -
# reg_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-09 21:40:00,063 - mmcv - INFO -
# atss_cls.weight - torch.Size([8, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2024-04-09 21:40:00,065 - mmcv - INFO -
# atss_cls.bias - torch.Size([8]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2024-04-09 21:40:00,066 - mmcv - INFO -
# atss_reg.weight - torch.Size([4, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:40:00,066 - mmcv - INFO -
# atss_reg.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:40:00,067 - mmcv - INFO -
# atss_centerness.weight - torch.Size([1, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:40:00,068 - mmcv - INFO -
# atss_centerness.bias - torch.Size([1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-09 21:40:00,068 - mmcv - INFO -
# scales.0.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-09 21:40:00,069 - mmcv - INFO -
# scales.1.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-09 21:40:00,069 - mmcv - INFO -
# scales.2.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-09 21:40:00,070 - mmcv - INFO -
# scales.3.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-09 21:40:00,070 - mmcv - INFO -
# scales.4.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of CoATSSHead
#
# 2024-04-09 21:40:00,071 - mmcv - INFO -
# scales.5.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of CoATSSHead

# %%
imagepath = "/raid/infolab/bhavyakohli/mmdet/Co-DETR/data/enumeration/test/train_13_0.png"
results = inference_detector(model, [imagepath] * 1)

# results contains upto 8 arrays of shape (num_proposals x 5)
# the first upto 8 elements are the bbox params, last element is the score
# the first entry is the proposal with the highest score

show_result_pyplot(model, imagepath, results[0])
[round(i[0][-1], 2) for i in results[0]]
# Out:
# [0.72, 0.62, 0.73, 0.22, 0.55, 0.53, 0.39, 0.41]

# %%
import cv2, matplotlib.pyplot as plt
import numpy as np

# %%
i1, i2 = 6,7
results[0][i1][0].astype(int), results[0][i2][0].astype(int)
# Out:
# (array([ 36,  53, 224, 252,   0]), array([ 36,  53, 224, 252,   0]))

# %%
image = cv2.imread(imagepath)
# for dic in results[0]:
dic = results[0][7]
x_min, y_min, x_max, y_max = dic[0][:-1]

thickness = 1
cv2.rectangle(image, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0, 255, 0), thickness)

plt.imshow(image)

# %%
found = {}
for n, boxes in enumerate([i[0][:-1] for i in results[0]]):
    found[n] = boxes
    # if boxes in found:
        # found.append(boxes)

# %%
found
# Out:
# {0: array([584.60535, 181.46101, 677.17236, 509.9118 ], dtype=float32),
#  1: array([524.6063 , 177.54582, 606.9541 , 493.9189 ], dtype=float32),
#  2: array([454.893  , 141.46487, 551.97437, 472.80222], dtype=float32),
#  3: array([325.55737, 121.06037, 426.2881 , 404.68954], dtype=float32),
#  4: array([325.55737, 121.06037, 426.2881 , 404.68954], dtype=float32),
#  5: array([126.2841  ,  69.257545, 278.20447 , 320.79483 ], dtype=float32),
#  6: array([ 36.82518 ,  53.455753, 224.16138 , 252.18124 ], dtype=float32),
#  7: array([ 36.82518 ,  53.455753, 224.16138 , 252.18124 ], dtype=float32)}

# %%
dir(model)
# Out:
# ['CLASSES',
#  'T_destination',
#  '__abstractmethods__',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_apply',
#  '_backward_hooks',
#  '_buffers',
#  '_call_impl',
#  '_dump_init_info',
#  '_forward_hooks',
#  '_forward_pre_hooks',
#  '_get_backward_hooks',
#  '_get_name',
#  '_is_full_backward_hook',
#  '_is_init',
#  '_load_from_state_dict',
#  '_load_state_dict_pre_hooks',
#  '_maybe_warn_non_full_backward_hook',
#  '_modules',
#  '_named_members',
#  '_non_persistent_buffers_set',
#  '_parameters',
#  '_parse_losses',
#  '_register_load_state_dict_pre_hook',
#  '_register_state_dict_hook',
#  '_replicate_for_data_parallel',
#  '_save_to_state_dict',
#  '_slow_forward',
#  '_state_dict_hooks',
#  '_version',
#  'add_module',
#  'aforward_test',
#  'apply',
#  'async_simple_test',
#  'aug_test',
#  'backbone',
#  'bbox_head',
#  'bfloat16',
#  'buffers',
#  'cfg',
#  'children',
#  'cpu',
#  'cuda',
#  'double',
#  'dump_patches',
#  'eval',
#  'eval_index',
#  'eval_module',
#  'extra_repr',
#  'extract_feat',
#  'extract_feats',
#  'float',
#  'forward',
#  'forward_dummy',
#  'forward_test',
#  'forward_train',
#  'fp16_enabled',
#  'get_buffer',
#  'get_extra_state',
#  'get_parameter',
#  'get_submodule',
#  'half',
#  'head_idx',
#  'init_cfg',
#  'init_weights',
#  'is_init',
#  'load_state_dict',
#  'modules',
#  'named_buffers',
#  'named_children',
#  'named_modules',
#  'named_parameters',
#  'neck',
#  'onnx_export',
#  'parameters',
#  'query_head',
#  'register_backward_hook',
#  'register_buffer',
#  'register_forward_hook',
#  'register_forward_pre_hook',
#  'register_full_backward_hook',
#  'register_module',
#  'register_parameter',
#  'requires_grad_',
#  'roi_head',
#  'rpn_head',
#  'set_extra_state',
#  'share_memory',
#  'show_result',
#  'simple_test',
#  'simple_test_bbox_head',
#  'simple_test_query_head',
#  'simple_test_roi_head',
#  'state_dict',
#  'test_cfg',
#  'to',
#  'to_empty',
#  'train',
#  'train_cfg',
#  'train_step',
#  'training',
#  'type',
#  'val_step',
#  'with_attn_mask',
#  'with_bbox',
#  'with_mask',
#  'with_neck',
#  'with_pos_coord',
#  'with_query_head',
#  'with_roi_head',
#  'with_rpn',
#  'with_shared_head',
#  'xpu',
#  'zero_grad']
