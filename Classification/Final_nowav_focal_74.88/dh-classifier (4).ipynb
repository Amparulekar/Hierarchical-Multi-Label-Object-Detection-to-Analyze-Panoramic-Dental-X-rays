# %%
# Import important libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from efficientnet_pytorch import EfficientNet
from torch.utils.data import DataLoader, random_split
from torch.optim.lr_scheduler import StepLR
from torch.optim.lr_scheduler import ReduceLROnPlateau
import copy
from torchvision import models, transforms, datasets
import pywt
import pywt.data
from pywt import dwt2, idwt2

# %%
# !pip install efficientnet_pytorch
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from efficientnet_pytorch) (2.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->efficientnet_pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->efficientnet_pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet_pytorch
#   Building wheel for efficientnet_pytorch (setup.py) ... done
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=1ce93dcfde17e50a81ef4f3c4a6ec2de1d8958c61dab7dae193d6d886fd08c7f
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet_pytorch
# Installing collected packages: efficientnet_pytorch
# Successfully installed efficientnet_pytorch-0.7.1

# %%
# Plots
TRAINING_LOSS = []
VALIDATION_LOSS = []
VALIDATION_ACCURACY = []
LEARNING_RATE = []

f = open("/kaggle/working/Log.txt", 'a')
f.truncate(0)
f.write("\n\n\n\n\n")

# If GPU is available then use GPU else use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

data_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize images to a fixed size
    transforms.ToTensor(),           # Convert images to PyTorch tensors
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize images
])

data_dir = "/kaggle/input/final-compressed-dss/Final_patches"  # Change this to your data directory
data = datasets.ImageFolder(root=data_dir , transform=data_transforms)
train_size = int(0.7 * len(data))  # 70% for training
val_size = int(0.15 * len(data))   # 15% for validation
test_size = len(data) - train_size - val_size  # Remaining for testing

train_dataset, val_dataset, test_dataset = random_split(data, [train_size, val_size, test_size])

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# Testing loop
def test(model, test_loader, device):
    model.eval()
    test_correct = 0
    test_total = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)  # Move data to CUDA if available
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            _, predicted = torch.max(outputs, 1)
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()
    test_accuracy = 100 * test_correct / test_total
    print(f'Testing Accuracy: {test_accuracy:.2f}%, Epochs: {epoch}')
    f.write(f'Testing Accuracy: {test_accuracy:.2f}%, Epochs: {epoch}\n')

# %%
# def wav(img):
#   img_list = []
#   # for i in range(img.shape[2]):
#   cA, (cH, cV, cD) = pywt.dwt2(img, 'haar')
#   img_list.extend([cA, cH, cV, cD])
#   return img_list

def wav(img):
  # img_list = []
  # for i in range(img.shape[2]):
  cA, (cH, cV, cD) = pywt.dwt2(img, 'haar')
  # img_list.extend([cA, cH, cV, cD])
  return cA, cH, cV, cD

def extract(imgs, R):
  out_list = []

  for i in range(imgs.shape[0]):
    img = imgs[i,:,:,:]
    prev_img = 0.2989 * img[0,:,:] + 0.5870 * img[1,:,:] + 0.1140 * img[2,:,:]
    # prev_img = prev_img.reshape((prev_img.shape[0], prev_img.shape[1], 1)).cpu()
    prev_img = prev_img.cpu()
    # print(prev_img.shape)
    
    for j in range(R):
        # print(f'orig img {prev_img}')
        trans_img= wav(prev_img)
        # print('hey')
        # print(trans_img[0].shape, len(trans_img))
        out = cv2.merge(trans_img)
        prev_img = out[:,:,0].copy()
    out_list.append(out[:,:,:4].flatten())
    
  return np.stack(out_list)

# %%
# class WaveNet(nn.Module):
#   def __init__(self, efficient_net, wavelet_in_fectures, R = 3):
#     super().__init__()
#     self.R = R
#     self.efficient_net = efficient_net
#     self.eff_in_features = efficient_net._fc.in_features
#     self.efficient_net._fc = nn.Identity()
#     self.wavelet_in_features = wavelet_in_fectures
#     self.out_features = num_classes
#     self.lin1=nn.Linear(in_features=self.wavelet_in_features,out_features=self.wavelet_in_features/3)
#     self.lin1=nn.Linear(in_features=self.wavelet_in_features/3,out_features=self.wavelet_in_features/9)
#     print(f"Efficient-net features:{self.eff_in_features}, Wavelet features:{self.wavelet_in_features/9}")
#     self.final_layer = nn.Linear(in_features=self.wavelet_in_features/9+self.eff_in_features, out_features=self.out_features)
#     # self.wav_block = 

#   def forward(self, inputs):
#     pre_final_eff = self.efficient_net(inputs).to(device)
#     wav = extract(inputs, self.R)
#     wav = torch.from_numpy(wav).to(device)
#     wav1 = self.lin1(wav)
#     wav2=self.lin2(wav1)
#     final_ip_feat = torch.cat((pre_final_eff, wav2), axis=1)
#     #final_ip_feat = pre_final_eff
#     output = self.final_layer(final_ip_feat)
#     return output

# %%
import torch
import torch.nn as nn

class WaveNet(nn.Module):
    def __init__(self, efficient_net, wavelet_in_features, num_classes, R=3):
        super().__init__()
        self.R = R
        self.efficient_net = efficient_net
        self.eff_in_features = efficient_net._fc.in_features
        self.efficient_net._fc = nn.Identity()
        self.wavelet_in_features = wavelet_in_features
        self.out_features = num_classes
        self.lin1 = nn.Linear(in_features=self.wavelet_in_features, out_features=self.wavelet_in_features // 9)
        print(f"Efficient-net features: {self.eff_in_features}, Wavelet features: {self.wavelet_in_features // 9}")
        self.final_layer = nn.Linear(in_features=self.wavelet_in_features // 9 + self.eff_in_features, out_features=self.out_features)

    def forward(self, inputs):
        pre_final_eff = self.efficient_net(inputs)
        #wav = extract(inputs, self.R)  # Assuming extract is defined elsewhere
        #wav = torch.from_numpy(wav).to(inputs.device)  # Assuming inputs.device gives the correct device
        #wav1 = self.lin1(wav)
        #final_ip_feat = torch.cat((pre_final_eff, wav1), dim=1)
        #output = self.final_layer(final_ip_feat)
        output = self.final_layer(pre_final_eff)
        return output

# %%
import cv2
im=cv2.imread('/kaggle/input/final-compressed-dss/Final_patches/0patches/patch_101_3_7_0.png')
print(im.shape)
# Out:
# (550, 380, 3)

# %%
model = EfficientNet.from_pretrained('efficientnet-b0')

net = WaveNet(model, wavelet_in_features,5).to(device)
print(summary(net))
# Out:
# Loaded pretrained weights for efficientnet-b0
# Efficient-net features: 1280, Wavelet features: 0
# /opt/conda/lib/python3.10/site-packages/torch/nn/init.py:412: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# ================================================================================
# Layer (type:depth-idx)                                  Param #
# ================================================================================
# WaveNet                                                 --
# ├─EfficientNet: 1-1                                     --
# │    └─Conv2dStaticSamePadding: 2-1                     864
# │    │    └─ZeroPad2d: 3-1                              --
# │    └─BatchNorm2d: 2-2                                 64
# │    └─ModuleList: 2-3                                  --
# │    │    └─MBConvBlock: 3-2                            1,448
# │    │    └─MBConvBlock: 3-3                            6,004
# │    │    └─MBConvBlock: 3-4                            10,710
# │    │    └─MBConvBlock: 3-5                            15,350
# │    │    └─MBConvBlock: 3-6                            31,290
# │    │    └─MBConvBlock: 3-7                            37,130
# │    │    └─MBConvBlock: 3-8                            102,900
# │    │    └─MBConvBlock: 3-9                            102,900
# │    │    └─MBConvBlock: 3-10                           126,004
# │    │    └─MBConvBlock: 3-11                           208,572
# │    │    └─MBConvBlock: 3-12                           208,572
# │    │    └─MBConvBlock: 3-13                           262,492
# │    │    └─MBConvBlock: 3-14                           587,952
# │    │    └─MBConvBlock: 3-15                           587,952
# │    │    └─MBConvBlock: 3-16                           587,952
# │    │    └─MBConvBlock: 3-17                           717,232
# │    └─Conv2dStaticSamePadding: 2-4                     409,600
# │    │    └─Identity: 3-18                              --
# │    └─BatchNorm2d: 2-5                                 2,560
# │    └─AdaptiveAvgPool2d: 2-6                           --
# │    └─Dropout: 2-7                                     --
# │    └─Identity: 2-8                                    --
# │    └─MemoryEfficientSwish: 2-9                        --
# ├─Linear: 1-2                                           --
# ├─Linear: 1-3                                           6,405
# ================================================================================
# Total params: 4,013,953
# Trainable params: 4,013,953
# Non-trainable params: 0
# ================================================================================

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2, reduction='mean'):
        super(FocalLoss, self).__init__()
        if alpha is not None:
            if not isinstance(alpha, (float, int, list)):
                raise ValueError("alpha must be a float, an integer, or a list")
            if isinstance(alpha, (float, int)):
                alpha = [alpha] * num_classes
            self.alpha = torch.tensor(alpha)
        else:
            self.alpha = None
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss

        if self.alpha is not None:
            if self.alpha.device != inputs.device:
                self.alpha = self.alpha.to(inputs.device)
            focal_loss = self.alpha[targets] * focal_loss

        if self.reduction == 'mean':
            return torch.mean(focal_loss)
        elif self.reduction == 'sum':
            return torch.sum(focal_loss)
        else:
            return focal_loss

# %%
compression_degree = 3
L = 550 #(224)
W = 380 #(224)
l=28
w=28
early_stopping = 40
BATCH_SIZE = 64
wavelet_in_features = 0#l*w*4
num_classes = 5
EPOCHS = 150
LOG_PATH = "/kaggle/working/Log.txt"
SAVE_PATH = '/kaggle/working/'
from torchinfo import summary
criterion = FocalLoss(alpha=[3, 1, 13, 3,1], gamma=2)
optimizer = optim.Adam(net.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=1,gamma=0.9)

print_every = 20
total_batches = len(train_loader)
max_val_accuracy = 0
stop_count = 0
running_loss = 0.0
epoch_loss = 0.0
val_loss = 0.0
num_epochs = EPOCHS
print(f"Number of batches: {total_batches}")
import cv2
early_stopping=5
# Out:
# Number of batches: 61

# %%
f = open("/kaggle/working/Log.txt", 'a')

TRAINING_LOSS = []
VALIDATION_LOSS = []
VALIDATION_ACCURACY = []
LEARNING_RATE = []

f = open(LOG_PATH, 'a')

for epoch in range(num_epochs):
    # Training loop
    if(stop_count > early_stopping or epoch == num_epochs):
        break

    net.train()
    for batch_idx, (inputs, labels) in enumerate(train_loader):
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        #print(inputs.shape)
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        if (batch_idx + 1) % print_every == 0 or (batch_idx + 1) == total_batches:
            avg_loss = running_loss / print_every
            print(f'Training Epoch - [{epoch+1}/{num_epochs}], Batch [{batch_idx+1}/{total_batches}], Loss: {avg_loss:.4f}')
            f.write(f'Training Epoch - [{epoch+1}/{num_epochs}], Batch [{batch_idx+1}/{total_batches}], Loss: {avg_loss:.4f}\n')
            epoch_loss += running_loss
            running_loss = 0
    epoch_loss = epoch_loss / len(train_loader)
    TRAINING_LOSS.append(epoch_loss)

    print(f'Epoch Loss: {epoch_loss:.4f}')
    # f.write(f'Epoch Loss: {epoch_loss:.4f}\n')

    epoch_loss = 0

    # Validation loop
    net.eval()
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)  # Move data to CUDA if available
            # print(inputs.shape)
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_loss = val_loss/len(val_loader)
    VALIDATION_LOSS.append(val_loss)

    val_accuracy = 100 * val_correct / val_total
    VALIDATION_ACCURACY.append(val_accuracy)

    LEARNING_RATE.append(optimizer.param_groups[-1]['lr'])

    # Stoping criteria
    if(val_accuracy > max_val_accuracy):
        max_val_accuracy = val_accuracy
        torch.save(net.state_dict(), f'{SAVE_PATH}epocha{epoch+1}.pth')
        stop_count = 0
    else:
        stop_count += 1

    scheduler.step()

    print(f'Validation - Epoch [{epoch+1}/{num_epochs}], Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.2f}%')
    f.write(f'Validation - Epoch [{epoch+1}/{num_epochs}], Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.2f}%\n')
    print(f"\nstop_count: {stop_count}")
f.close()
# Out:
# Training Epoch - [1/150], Batch [20/61], Loss: 1.3436
# Training Epoch - [1/150], Batch [40/61], Loss: 1.0092
# Training Epoch - [1/150], Batch [60/61], Loss: 1.1056
# Training Epoch - [1/150], Batch [61/61], Loss: 0.1468
# Epoch Loss: 1.1820
# Validation - Epoch [1/150], Loss: 3.0972, Accuracy: 42.65%
#
# stop_count: 0
# Training Epoch - [2/150], Batch [20/61], Loss: 0.7539
# Training Epoch - [2/150], Batch [40/61], Loss: 0.6624
# Training Epoch - [2/150], Batch [60/61], Loss: 0.6212
# Training Epoch - [2/150], Batch [61/61], Loss: 0.0644
# Epoch Loss: 0.6892
# Validation - Epoch [2/150], Loss: 2.5768, Accuracy: 57.95%
#
# stop_count: 0
# Training Epoch - [3/150], Batch [20/61], Loss: 0.4421
# Training Epoch - [3/150], Batch [40/61], Loss: 0.4405
# Training Epoch - [3/150], Batch [60/61], Loss: 0.5137
# Training Epoch - [3/150], Batch [61/61], Loss: 0.0344
# Epoch Loss: 0.4691
# Validation - Epoch [3/150], Loss: 1.5254, Accuracy: 63.61%
#
# stop_count: 0
# Training Epoch - [4/150], Batch [20/61], Loss: 0.3209
# Training Epoch - [4/150], Batch [40/61], Loss: 0.3944
# Training Epoch - [4/150], Batch [60/61], Loss: 0.2869
# Training Epoch - [4/150], Batch [61/61], Loss: 0.0052
# Epoch Loss: 0.3303
# Validation - Epoch [4/150], Loss: 1.0319, Accuracy: 66.02%
#
# stop_count: 0
# Training Epoch - [5/150], Batch [20/61], Loss: 0.2317
# Training Epoch - [5/150], Batch [40/61], Loss: 0.2260
# Training Epoch - [5/150], Batch [60/61], Loss: 0.2962
# Training Epoch - [5/150], Batch [61/61], Loss: 0.0116
# Epoch Loss: 0.2510
# Validation - Epoch [5/150], Loss: 1.2858, Accuracy: 72.05%
#
# stop_count: 0
# Training Epoch - [6/150], Batch [20/61], Loss: 0.1861
# Training Epoch - [6/150], Batch [40/61], Loss: 0.1514
# Training Epoch - [6/150], Batch [60/61], Loss: 0.1869
# Training Epoch - [6/150], Batch [61/61], Loss: 0.0114
# Epoch Loss: 0.1757
# Validation - Epoch [6/150], Loss: 1.5701, Accuracy: 43.98%
#
# stop_count: 1
# Training Epoch - [7/150], Batch [20/61], Loss: 0.1066
# Training Epoch - [7/150], Batch [40/61], Loss: 0.1207
# Training Epoch - [7/150], Batch [60/61], Loss: 0.0966
# Training Epoch - [7/150], Batch [61/61], Loss: 0.0041
# Epoch Loss: 0.1075
# Validation - Epoch [7/150], Loss: 1.1947, Accuracy: 73.61%
#
# stop_count: 0
# Training Epoch - [8/150], Batch [20/61], Loss: 0.0611
# Training Epoch - [8/150], Batch [40/61], Loss: 0.0789
# Training Epoch - [8/150], Batch [60/61], Loss: 0.0953
# Training Epoch - [8/150], Batch [61/61], Loss: 0.0074
# Epoch Loss: 0.0796
# Validation - Epoch [8/150], Loss: 1.0804, Accuracy: 71.57%
#
# stop_count: 1
# Training Epoch - [9/150], Batch [20/61], Loss: 0.0559
# Training Epoch - [9/150], Batch [40/61], Loss: 0.0500
# Training Epoch - [9/150], Batch [60/61], Loss: 0.0594
# Training Epoch - [9/150], Batch [61/61], Loss: 0.0016
# Epoch Loss: 0.0547
# Validation - Epoch [9/150], Loss: 1.5414, Accuracy: 70.24%
#
# stop_count: 2
# Training Epoch - [10/150], Batch [20/61], Loss: 0.0503
# Training Epoch - [10/150], Batch [40/61], Loss: 0.0452
# Training Epoch - [10/150], Batch [60/61], Loss: 0.0441
# Training Epoch - [10/150], Batch [61/61], Loss: 0.0012
# Epoch Loss: 0.0461
# Validation - Epoch [10/150], Loss: 0.9615, Accuracy: 72.17%
#
# stop_count: 3
# Training Epoch - [11/150], Batch [20/61], Loss: 0.0459
# Training Epoch - [11/150], Batch [40/61], Loss: 0.0816
# Training Epoch - [11/150], Batch [60/61], Loss: 0.0515
# Training Epoch - [11/150], Batch [61/61], Loss: 0.0036
# Epoch Loss: 0.0599
# Validation - Epoch [11/150], Loss: 1.3125, Accuracy: 75.18%
#
# stop_count: 0
# Training Epoch - [12/150], Batch [20/61], Loss: 0.0255
# Training Epoch - [12/150], Batch [40/61], Loss: 0.0265
# Training Epoch - [12/150], Batch [60/61], Loss: 0.0377
# Training Epoch - [12/150], Batch [61/61], Loss: 0.0007
# Epoch Loss: 0.0297
# Validation - Epoch [12/150], Loss: 1.1173, Accuracy: 73.25%
#
# stop_count: 1
# Training Epoch - [13/150], Batch [20/61], Loss: 0.0161
# Training Epoch - [13/150], Batch [40/61], Loss: 0.0177
# Training Epoch - [13/150], Batch [60/61], Loss: 0.0427
# Training Epoch - [13/150], Batch [61/61], Loss: 0.0034
# Epoch Loss: 0.0262
# Validation - Epoch [13/150], Loss: 0.9510, Accuracy: 72.89%
#
# stop_count: 2
# Training Epoch - [14/150], Batch [20/61], Loss: 0.0406
# Training Epoch - [14/150], Batch [40/61], Loss: 0.0305
# Training Epoch - [14/150], Batch [60/61], Loss: 0.0205
# Training Epoch - [14/150], Batch [61/61], Loss: 0.0057
# Epoch Loss: 0.0319
# Validation - Epoch [14/150], Loss: 1.1438, Accuracy: 77.83%
#
# stop_count: 0
# Training Epoch - [15/150], Batch [20/61], Loss: 0.0179
# Training Epoch - [15/150], Batch [40/61], Loss: 0.0226
# Training Epoch - [15/150], Batch [60/61], Loss: 0.0227
# Training Epoch - [15/150], Batch [61/61], Loss: 0.0003
# Epoch Loss: 0.0208
# Validation - Epoch [15/150], Loss: 0.8950, Accuracy: 72.05%
#
# stop_count: 1
# Training Epoch - [16/150], Batch [20/61], Loss: 0.0134
# Training Epoch - [16/150], Batch [40/61], Loss: 0.0115
# Training Epoch - [16/150], Batch [60/61], Loss: 0.0114
# Training Epoch - [16/150], Batch [61/61], Loss: 0.0071
# Epoch Loss: 0.0142
# Validation - Epoch [16/150], Loss: 1.0433, Accuracy: 75.42%
#
# stop_count: 2
# Training Epoch - [17/150], Batch [20/61], Loss: 0.0091
# Training Epoch - [17/150], Batch [40/61], Loss: 0.0138
# Training Epoch - [17/150], Batch [60/61], Loss: 0.0103
# Training Epoch - [17/150], Batch [61/61], Loss: 0.0001
# Epoch Loss: 0.0109
# Validation - Epoch [17/150], Loss: 1.1328, Accuracy: 76.75%
#
# stop_count: 3
# Training Epoch - [18/150], Batch [20/61], Loss: 0.0087
# Training Epoch - [18/150], Batch [40/61], Loss: 0.0083
# Training Epoch - [18/150], Batch [60/61], Loss: 0.0076
# Training Epoch - [18/150], Batch [61/61], Loss: 0.0006
# Epoch Loss: 0.0083
# Validation - Epoch [18/150], Loss: 1.1795, Accuracy: 77.59%
#
# stop_count: 4
# Training Epoch - [19/150], Batch [20/61], Loss: 0.0066
# Training Epoch - [19/150], Batch [40/61], Loss: 0.0081
# Training Epoch - [19/150], Batch [60/61], Loss: 0.0091
# Training Epoch - [19/150], Batch [61/61], Loss: 0.0017
# Epoch Loss: 0.0084
# Validation - Epoch [19/150], Loss: 1.2752, Accuracy: 76.63%
#
# stop_count: 5
# Training Epoch - [20/150], Batch [20/61], Loss: 0.0062
# Training Epoch - [20/150], Batch [40/61], Loss: 0.0063
# Training Epoch - [20/150], Batch [60/61], Loss: 0.0102
# Training Epoch - [20/150], Batch [61/61], Loss: 0.0007
# Epoch Loss: 0.0077
# Validation - Epoch [20/150], Loss: 1.3121, Accuracy: 77.35%
#
# stop_count: 6

# %%
import matplotlib.pyplot as plt
plt.plot([epoch for epoch in range(20)], TRAINING_LOSS)
plt.title('Training Loss')
plt.show()
plt.plot([epoch for epoch in range(20)], VALIDATION_LOSS)
plt.title('Validation Loss')
plt.show()
plt.plot([epoch for epoch in range(20)], VALIDATION_ACCURACY)
plt.title('Validation Accuracy')
plt.show()

# %%
f = open('/kaggle/working/Log.txt', 'a')
PATH = '/kaggle/working/epocha14.pth'
model = EfficientNet.from_pretrained('efficientnet-b0')
best_model = WaveNet(model, wavelet_in_features, 5).to(device) 
best_model.load_state_dict(torch.load(PATH))
best_model.to(device)
test(best_model, test_loader, device)
f.close()
# Out:
# Loaded pretrained weights for efficientnet-b0
# Efficient-net features: 1280, Wavelet features: 0
# Testing Accuracy: 74.88%, Epochs: 20
