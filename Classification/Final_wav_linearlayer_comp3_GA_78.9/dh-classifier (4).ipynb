# %%
# Import important libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from efficientnet_pytorch import EfficientNet
from torch.utils.data import DataLoader, random_split
from torch.optim.lr_scheduler import StepLR
from torch.optim.lr_scheduler import ReduceLROnPlateau
import copy
from torchvision import models, transforms, datasets
import pywt
import pywt.data
from pywt import dwt2, idwt2

# %%
# !pip install efficientnet_pytorch
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from efficientnet_pytorch) (2.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->efficientnet_pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->efficientnet_pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet_pytorch
#   Building wheel for efficientnet_pytorch (setup.py) ... done
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=4007eb91af71722b236fad0d603affc4ad73655563a3c10e2f287465cc97e070
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet_pytorch
# Installing collected packages: efficientnet_pytorch
# Successfully installed efficientnet_pytorch-0.7.1

# %%
# Plots
TRAINING_LOSS = []
VALIDATION_LOSS = []
VALIDATION_ACCURACY = []
LEARNING_RATE = []

f = open("/kaggle/working/Log.txt", 'a')
f.truncate(0)
f.write("\n\n\n\n\n")

# If GPU is available then use GPU else use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

import torch
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
import numpy as np

class AugmentedSubset(torch.utils.data.Dataset):
    def __init__(self, dataset, classes_to_augment, augmentation_transform):
        self.dataset = dataset
        self.classes_to_augment = classes_to_augment
        self.augmentation_transform = augmentation_transform
    def __getitem__(self, index):
        image, label = self.dataset[index]
        # Check if the label corresponds to a class to augment
        if label in self.classes_to_augment:
            # Apply augmentation
            image = self.augmentation_transform(image)
        return image, label
    def __len__(self):
        return len(self.dataset)
# Define transforms for training and validation
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),  # Random horizontal flip
    transforms.RandomVerticalFlip()  # Convert to tensor
])

data_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize images to a fixed size
    transforms.ToTensor(),           # Convert images to PyTorch tensors
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize images
])

data_dir = "/kaggle/input/final-compressed-dss/Final_patches"  # Change this to your data directory
data = datasets.ImageFolder(root=data_dir , transform=data_transforms)
train_size = int(0.7 * len(data))  # 70% for training
val_size = int(0.15 * len(data))   # 15% for validation
test_size = len(data) - train_size - val_size  # Remaining for testing

original_train_data, val_dataset, test_dataset = random_split(data, [train_size, val_size, test_size])
# Define classes to augment
classes_to_augment = [0,2,3]  # Example: classes 0, 1, and 2 will have augmentation

# Create augmented dataset with on-the-fly augmentation
augmented_train_data = AugmentedSubset(original_train_data, classes_to_augment, train_transform)

train_loader = torch.utils.data.DataLoader(augmented_train_data, batch_size=64, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# Testing loop
def test(model, test_loader, device):
    model.eval()
    test_correct = 0
    test_total = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)  # Move data to CUDA if available
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            _, predicted = torch.max(outputs, 1)
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()
    test_accuracy = 100 * test_correct / test_total
    print(f'Testing Accuracy: {test_accuracy:.2f}%, Epochs: {epoch}')
    f.write(f'Testing Accuracy: {test_accuracy:.2f}%, Epochs: {epoch}\n')

# %%
# def wav(img):
#   img_list = []
#   # for i in range(img.shape[2]):
#   cA, (cH, cV, cD) = pywt.dwt2(img, 'haar')
#   img_list.extend([cA, cH, cV, cD])
#   return img_list

def wav(img):
  # img_list = []
  # for i in range(img.shape[2]):
  cA, (cH, cV, cD) = pywt.dwt2(img, 'haar')
  # img_list.extend([cA, cH, cV, cD])
  return cA, cH, cV, cD

def extract(imgs, R):
  out_list = []

  for i in range(imgs.shape[0]):
    img = imgs[i,:,:,:]
    prev_img = 0.2989 * img[0,:,:] + 0.5870 * img[1,:,:] + 0.1140 * img[2,:,:]
    # prev_img = prev_img.reshape((prev_img.shape[0], prev_img.shape[1], 1)).cpu()
    prev_img = prev_img.cpu()
    # print(prev_img.shape)
    
    for j in range(R):
        # print(f'orig img {prev_img}')
        trans_img= wav(prev_img)
        # print('hey')
        # print(trans_img[0].shape, len(trans_img))
        out = cv2.merge(trans_img)
        prev_img = out[:,:,0].copy()
    out_list.append(out[:,:,:4].flatten())
    
  return np.stack(out_list)

# %%
# class WaveNet(nn.Module):
#   def __init__(self, efficient_net, wavelet_in_fectures, R = 3):
#     super().__init__()
#     self.R = R
#     self.efficient_net = efficient_net
#     self.eff_in_features = efficient_net._fc.in_features
#     self.efficient_net._fc = nn.Identity()
#     self.wavelet_in_features = wavelet_in_fectures
#     self.out_features = num_classes
#     self.lin1=nn.Linear(in_features=self.wavelet_in_features,out_features=self.wavelet_in_features/3)
#     self.lin1=nn.Linear(in_features=self.wavelet_in_features/3,out_features=self.wavelet_in_features/9)
#     print(f"Efficient-net features:{self.eff_in_features}, Wavelet features:{self.wavelet_in_features/9}")
#     self.final_layer = nn.Linear(in_features=self.wavelet_in_features/9+self.eff_in_features, out_features=self.out_features)
#     # self.wav_block = 

#   def forward(self, inputs):
#     pre_final_eff = self.efficient_net(inputs).to(device)
#     wav = extract(inputs, self.R)
#     wav = torch.from_numpy(wav).to(device)
#     wav1 = self.lin1(wav)
#     wav2=self.lin2(wav1)
#     final_ip_feat = torch.cat((pre_final_eff, wav2), axis=1)
#     #final_ip_feat = pre_final_eff
#     output = self.final_layer(final_ip_feat)
#     return output

# %%
import torch
import torch.nn as nn

class WaveNet(nn.Module):
    def __init__(self, efficient_net, wavelet_in_features, num_classes, R=3):
        super().__init__()
        self.R = R
        self.efficient_net = efficient_net
        self.eff_in_features = efficient_net._fc.in_features
        self.efficient_net._fc = nn.Identity()
        self.wavelet_in_features = wavelet_in_features
        self.out_features = num_classes
        self.lin1 = nn.Linear(in_features=self.wavelet_in_features, out_features=self.wavelet_in_features // 9)
        print(f"Efficient-net features: {self.eff_in_features}, Wavelet features: {self.wavelet_in_features // 9}")
        self.final_layer = nn.Linear(in_features=self.wavelet_in_features // 9 + self.eff_in_features, out_features=self.out_features)

    def forward(self, inputs):
        pre_final_eff = self.efficient_net(inputs)
        wav = extract(inputs, self.R)  # Assuming extract is defined elsewhere
        wav = torch.from_numpy(wav).to(inputs.device)  # Assuming inputs.device gives the correct device
        wav1 = self.lin1(wav)
        final_ip_feat = torch.cat((pre_final_eff, wav1), dim=1)
        output = self.final_layer(final_ip_feat)
        return output

# %%
import cv2
im=cv2.imread('/kaggle/input/final-compressed-dss/Final_patches/0patches/patch_101_3_7_0.png')
print(im.shape)
# Out:
# (550, 380, 3)

# %%
model = EfficientNet.from_pretrained('efficientnet-b0')

net = WaveNet(model, wavelet_in_features,5).to(device)
print(summary(net))
# Out:
# Loaded pretrained weights for efficientnet-b0
# Efficient-net features: 1280, Wavelet features: 348
# ================================================================================
# Layer (type:depth-idx)                                  Param #
# ================================================================================
# WaveNet                                                 --
# ├─EfficientNet: 1-1                                     --
# │    └─Conv2dStaticSamePadding: 2-1                     864
# │    │    └─ZeroPad2d: 3-1                              --
# │    └─BatchNorm2d: 2-2                                 64
# │    └─ModuleList: 2-3                                  --
# │    │    └─MBConvBlock: 3-2                            1,448
# │    │    └─MBConvBlock: 3-3                            6,004
# │    │    └─MBConvBlock: 3-4                            10,710
# │    │    └─MBConvBlock: 3-5                            15,350
# │    │    └─MBConvBlock: 3-6                            31,290
# │    │    └─MBConvBlock: 3-7                            37,130
# │    │    └─MBConvBlock: 3-8                            102,900
# │    │    └─MBConvBlock: 3-9                            102,900
# │    │    └─MBConvBlock: 3-10                           126,004
# │    │    └─MBConvBlock: 3-11                           208,572
# │    │    └─MBConvBlock: 3-12                           208,572
# │    │    └─MBConvBlock: 3-13                           262,492
# │    │    └─MBConvBlock: 3-14                           587,952
# │    │    └─MBConvBlock: 3-15                           587,952
# │    │    └─MBConvBlock: 3-16                           587,952
# │    │    └─MBConvBlock: 3-17                           717,232
# │    └─Conv2dStaticSamePadding: 2-4                     409,600
# │    │    └─Identity: 3-18                              --
# │    └─BatchNorm2d: 2-5                                 2,560
# │    └─AdaptiveAvgPool2d: 2-6                           --
# │    └─Dropout: 2-7                                     --
# │    └─Identity: 2-8                                    --
# │    └─MemoryEfficientSwish: 2-9                        --
# ├─Linear: 1-2                                           1,091,676
# ├─Linear: 1-3                                           8,145
# ================================================================================
# Total params: 5,107,369
# Trainable params: 5,107,369
# Non-trainable params: 0
# ================================================================================

# %%
compression_degree = 3
L = 550 #(224)
W = 380 #(224)
l=28
w=28
early_stopping = 40
BATCH_SIZE = 64
wavelet_in_features = 3136#l*w*4
num_classes = 5
EPOCHS = 150
LOG_PATH = "/kaggle/working/Log.txt"
SAVE_PATH = '/kaggle/working/'
from torchinfo import summary
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=1,gamma=0.9)

print_every = 20
total_batches = len(train_loader)
max_val_accuracy = 0
stop_count = 0
running_loss = 0.0
epoch_loss = 0.0
val_loss = 0.0
num_epochs = EPOCHS
print(f"Number of batches: {total_batches}")
import cv2
early_stopping=5
# Out:
# Number of batches: 61

# %%
f = open("/kaggle/working/Log.txt", 'a')

TRAINING_LOSS = []
VALIDATION_LOSS = []
VALIDATION_ACCURACY = []
LEARNING_RATE = []

f = open(LOG_PATH, 'a')

for epoch in range(num_epochs):
    # Training loop
    if(stop_count > early_stopping or epoch == num_epochs):
        break

    net.train()
    for batch_idx, (inputs, labels) in enumerate(train_loader):
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        #print(inputs.shape)
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        if (batch_idx + 1) % print_every == 0 or (batch_idx + 1) == total_batches:
            avg_loss = running_loss / print_every
            print(f'Training Epoch - [{epoch+1}/{num_epochs}], Batch [{batch_idx+1}/{total_batches}], Loss: {avg_loss:.4f}')
            f.write(f'Training Epoch - [{epoch+1}/{num_epochs}], Batch [{batch_idx+1}/{total_batches}], Loss: {avg_loss:.4f}\n')
            epoch_loss += running_loss
            running_loss = 0
    epoch_loss = epoch_loss / len(train_loader)
    TRAINING_LOSS.append(epoch_loss)

    print(f'Epoch Loss: {epoch_loss:.4f}')
    # f.write(f'Epoch Loss: {epoch_loss:.4f}\n')

    epoch_loss = 0

    # Validation loop
    net.eval()
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)  # Move data to CUDA if available
            # print(inputs.shape)
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_loss = val_loss/len(val_loader)
    VALIDATION_LOSS.append(val_loss)

    val_accuracy = 100 * val_correct / val_total
    VALIDATION_ACCURACY.append(val_accuracy)

    LEARNING_RATE.append(optimizer.param_groups[-1]['lr'])

    # Stoping criteria
    if(val_accuracy > max_val_accuracy):
        max_val_accuracy = val_accuracy
        torch.save(net.state_dict(), f'{SAVE_PATH}epoch{epoch+1}.pth')
        stop_count = 0
    else:
        stop_count += 1

    scheduler.step()

    print(f'Validation - Epoch [{epoch+1}/{num_epochs}], Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.2f}%')
    f.write(f'Validation - Epoch [{epoch+1}/{num_epochs}], Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.2f}%\n')
    print(f"\nstop_count: {stop_count}")
f.close()
# Out:
# Training Epoch - [1/150], Batch [20/61], Loss: 8.0141
# Training Epoch - [1/150], Batch [40/61], Loss: 1.5030
# Training Epoch - [1/150], Batch [60/61], Loss: 1.0331
# Training Epoch - [1/150], Batch [61/61], Loss: 0.0578
# Epoch Loss: 3.4780
# Validation - Epoch [1/150], Loss: 1.1500, Accuracy: 63.61%
#
# stop_count: 0
# Training Epoch - [2/150], Batch [20/61], Loss: 0.7626
# Training Epoch - [2/150], Batch [40/61], Loss: 0.7081
# Training Epoch - [2/150], Batch [60/61], Loss: 0.6561
# Training Epoch - [2/150], Batch [61/61], Loss: 0.0267
# Epoch Loss: 0.7061
# Validation - Epoch [2/150], Loss: 1.2312, Accuracy: 65.06%
#
# stop_count: 0
# Training Epoch - [3/150], Batch [20/61], Loss: 0.5751
# Training Epoch - [3/150], Batch [40/61], Loss: 0.6207
# Training Epoch - [3/150], Batch [60/61], Loss: 0.5824
# Training Epoch - [3/150], Batch [61/61], Loss: 0.0388
# Epoch Loss: 0.5957
# Validation - Epoch [3/150], Loss: 1.7018, Accuracy: 56.51%
#
# stop_count: 1
# Training Epoch - [4/150], Batch [20/61], Loss: 0.4486
# Training Epoch - [4/150], Batch [40/61], Loss: 0.4123
# Training Epoch - [4/150], Batch [60/61], Loss: 0.4434
# Training Epoch - [4/150], Batch [61/61], Loss: 0.0191
# Epoch Loss: 0.4339
# Validation - Epoch [4/150], Loss: 1.1629, Accuracy: 69.52%
#
# stop_count: 0
# Training Epoch - [5/150], Batch [20/61], Loss: 0.3634
# Training Epoch - [5/150], Batch [40/61], Loss: 0.3724
# Training Epoch - [5/150], Batch [60/61], Loss: 0.3254
# Training Epoch - [5/150], Batch [61/61], Loss: 0.0211
# Epoch Loss: 0.3548
# Validation - Epoch [5/150], Loss: 1.2188, Accuracy: 66.63%
#
# stop_count: 1
# Training Epoch - [6/150], Batch [20/61], Loss: 0.2468
# Training Epoch - [6/150], Batch [40/61], Loss: 0.2561
# Training Epoch - [6/150], Batch [60/61], Loss: 0.2448
# Training Epoch - [6/150], Batch [61/61], Loss: 0.0257
# Epoch Loss: 0.2535
# Validation - Epoch [6/150], Loss: 0.9939, Accuracy: 70.84%
#
# stop_count: 0
# Training Epoch - [7/150], Batch [20/61], Loss: 0.2034
# Training Epoch - [7/150], Batch [40/61], Loss: 0.2026
# Training Epoch - [7/150], Batch [60/61], Loss: 0.1820
# Training Epoch - [7/150], Batch [61/61], Loss: 0.0079
# Epoch Loss: 0.1954
# Validation - Epoch [7/150], Loss: 1.3166, Accuracy: 71.69%
#
# stop_count: 0
# Training Epoch - [8/150], Batch [20/61], Loss: 0.1726
# Training Epoch - [8/150], Batch [40/61], Loss: 0.1502
# Training Epoch - [8/150], Batch [60/61], Loss: 0.1237
# Training Epoch - [8/150], Batch [61/61], Loss: 0.0040
# Epoch Loss: 0.1477
# Validation - Epoch [8/150], Loss: 1.1119, Accuracy: 73.61%
#
# stop_count: 0
# Training Epoch - [9/150], Batch [20/61], Loss: 0.1223
# Training Epoch - [9/150], Batch [40/61], Loss: 0.0952
# Training Epoch - [9/150], Batch [60/61], Loss: 0.1185
# Training Epoch - [9/150], Batch [61/61], Loss: 0.0022
# Epoch Loss: 0.1109
# Validation - Epoch [9/150], Loss: 1.1514, Accuracy: 72.77%
#
# stop_count: 1
# Training Epoch - [10/150], Batch [20/61], Loss: 0.0895
# Training Epoch - [10/150], Batch [40/61], Loss: 0.1065
# Training Epoch - [10/150], Batch [60/61], Loss: 0.0827
# Training Epoch - [10/150], Batch [61/61], Loss: 0.0072
# Epoch Loss: 0.0937
# Validation - Epoch [10/150], Loss: 1.0843, Accuracy: 76.99%
#
# stop_count: 0
# Training Epoch - [11/150], Batch [20/61], Loss: 0.0739
# Training Epoch - [11/150], Batch [40/61], Loss: 0.0557
# Training Epoch - [11/150], Batch [60/61], Loss: 0.0746
# Training Epoch - [11/150], Batch [61/61], Loss: 0.0045
# Epoch Loss: 0.0684
# Validation - Epoch [11/150], Loss: 1.1119, Accuracy: 74.10%
#
# stop_count: 1
# Training Epoch - [12/150], Batch [20/61], Loss: 0.0486
# Training Epoch - [12/150], Batch [40/61], Loss: 0.0534
# Training Epoch - [12/150], Batch [60/61], Loss: 0.0678
# Training Epoch - [12/150], Batch [61/61], Loss: 0.0069
# Epoch Loss: 0.0579
# Validation - Epoch [12/150], Loss: 1.2474, Accuracy: 75.90%
#
# stop_count: 2
# Training Epoch - [13/150], Batch [20/61], Loss: 0.0423
# Training Epoch - [13/150], Batch [40/61], Loss: 0.0424
# Training Epoch - [13/150], Batch [60/61], Loss: 0.0652
# Training Epoch - [13/150], Batch [61/61], Loss: 0.0003
# Epoch Loss: 0.0492
# Validation - Epoch [13/150], Loss: 1.2636, Accuracy: 73.61%
#
# stop_count: 3
# Training Epoch - [14/150], Batch [20/61], Loss: 0.0348
# Training Epoch - [14/150], Batch [40/61], Loss: 0.0284
# Training Epoch - [14/150], Batch [60/61], Loss: 0.0377
# Training Epoch - [14/150], Batch [61/61], Loss: 0.0050
# Epoch Loss: 0.0347
# Validation - Epoch [14/150], Loss: 1.2025, Accuracy: 77.11%
#
# stop_count: 0
# Training Epoch - [15/150], Batch [20/61], Loss: 0.0407
# Training Epoch - [15/150], Batch [40/61], Loss: 0.0339
# Training Epoch - [15/150], Batch [60/61], Loss: 0.0320
# Training Epoch - [15/150], Batch [61/61], Loss: 0.0032
# Epoch Loss: 0.0360
# Validation - Epoch [15/150], Loss: 1.4493, Accuracy: 74.94%
#
# stop_count: 1
# Training Epoch - [16/150], Batch [20/61], Loss: 0.0218
# Training Epoch - [16/150], Batch [40/61], Loss: 0.0193
# Training Epoch - [16/150], Batch [60/61], Loss: 0.0242
# Training Epoch - [16/150], Batch [61/61], Loss: 0.0010
# Epoch Loss: 0.0217
# Validation - Epoch [16/150], Loss: 1.2595, Accuracy: 76.02%
#
# stop_count: 2
# Training Epoch - [17/150], Batch [20/61], Loss: 0.0169
# Training Epoch - [17/150], Batch [40/61], Loss: 0.0180
# Training Epoch - [17/150], Batch [60/61], Loss: 0.0320
# Training Epoch - [17/150], Batch [61/61], Loss: 0.0001
# Epoch Loss: 0.0220
# Validation - Epoch [17/150], Loss: 1.2578, Accuracy: 76.99%
#
# stop_count: 3
# Training Epoch - [18/150], Batch [20/61], Loss: 0.0149
# Training Epoch - [18/150], Batch [40/61], Loss: 0.0171
# Training Epoch - [18/150], Batch [60/61], Loss: 0.0137
# Training Epoch - [18/150], Batch [61/61], Loss: 0.0005
# Epoch Loss: 0.0152
# Validation - Epoch [18/150], Loss: 1.2132, Accuracy: 76.99%
#
# stop_count: 4
# Training Epoch - [19/150], Batch [20/61], Loss: 0.0115
# Training Epoch - [19/150], Batch [40/61], Loss: 0.0331
# Training Epoch - [19/150], Batch [60/61], Loss: 0.0275
# Training Epoch - [19/150], Batch [61/61], Loss: 0.0025
# Epoch Loss: 0.0244
# Validation - Epoch [19/150], Loss: 1.2062, Accuracy: 76.02%
#
# stop_count: 5
# Training Epoch - [20/150], Batch [20/61], Loss: 0.0158
# Training Epoch - [20/150], Batch [40/61], Loss: 0.0104
# Training Epoch - [20/150], Batch [60/61], Loss: 0.0094
# Training Epoch - [20/150], Batch [61/61], Loss: 0.0005
# Epoch Loss: 0.0118
# Validation - Epoch [20/150], Loss: 1.2515, Accuracy: 78.07%
#
# stop_count: 0
# Training Epoch - [21/150], Batch [20/61], Loss: 0.0289
# Training Epoch - [21/150], Batch [40/61], Loss: 0.0111
# Training Epoch - [21/150], Batch [60/61], Loss: 0.0120
# Training Epoch - [21/150], Batch [61/61], Loss: 0.0014
# Epoch Loss: 0.0175
# Validation - Epoch [21/150], Loss: 1.1873, Accuracy: 77.11%
#
# stop_count: 1
# Training Epoch - [22/150], Batch [20/61], Loss: 0.0132
# Training Epoch - [22/150], Batch [40/61], Loss: 0.0058
# Training Epoch - [22/150], Batch [60/61], Loss: 0.0142
# Training Epoch - [22/150], Batch [61/61], Loss: 0.0006
# Epoch Loss: 0.0111
# Validation - Epoch [22/150], Loss: 1.2332, Accuracy: 77.23%
#
# stop_count: 2
# Training Epoch - [23/150], Batch [20/61], Loss: 0.0082
# Training Epoch - [23/150], Batch [40/61], Loss: 0.0096
# Training Epoch - [23/150], Batch [60/61], Loss: 0.0094
# Training Epoch - [23/150], Batch [61/61], Loss: 0.0001
# Epoch Loss: 0.0090
# Validation - Epoch [23/150], Loss: 1.3109, Accuracy: 76.75%
#
# stop_count: 3
# Training Epoch - [24/150], Batch [20/61], Loss: 0.0091
# Training Epoch - [24/150], Batch [40/61], Loss: 0.0100
# Training Epoch - [24/150], Batch [60/61], Loss: 0.0109
# Training Epoch - [24/150], Batch [61/61], Loss: 0.0008
# Epoch Loss: 0.0101
# Validation - Epoch [24/150], Loss: 1.3222, Accuracy: 77.11%
#
# stop_count: 4
# Training Epoch - [25/150], Batch [20/61], Loss: 0.0056
# Training Epoch - [25/150], Batch [40/61], Loss: 0.0112
# Training Epoch - [25/150], Batch [60/61], Loss: 0.0057
# Training Epoch - [25/150], Batch [61/61], Loss: 0.0006
# Epoch Loss: 0.0076
# Validation - Epoch [25/150], Loss: 1.3820, Accuracy: 76.87%
#
# stop_count: 5
# Training Epoch - [26/150], Batch [20/61], Loss: 0.0052
# Training Epoch - [26/150], Batch [40/61], Loss: 0.0065
# Training Epoch - [26/150], Batch [60/61], Loss: 0.0089
# Training Epoch - [26/150], Batch [61/61], Loss: 0.0022
# Epoch Loss: 0.0074
# Validation - Epoch [26/150], Loss: 1.3487, Accuracy: 76.63%
#
# stop_count: 6

# %%
import matplotlib.pyplot as plt
plt.plot([epoch for epoch in range(26)], TRAINING_LOSS)
plt.title('Training Loss')
plt.show()
plt.plot([epoch for epoch in range(26)], VALIDATION_LOSS)
plt.title('Validation Loss')
plt.show()
plt.plot([epoch for epoch in range(26)], VALIDATION_ACCURACY)
plt.title('Validation Accuracy')
plt.show()

# %%
f = open('/kaggle/working/Log.txt', 'a')
PATH = '/kaggle/working/epoch20.pth'
model = EfficientNet.from_pretrained('efficientnet-b0')
best_model = WaveNet(model, wavelet_in_features, 5).to(device) 
best_model.load_state_dict(torch.load(PATH))
best_model.to(device)
test(best_model, test_loader, device)
f.close()
# Out:
# Loaded pretrained weights for efficientnet-b0
# Efficient-net features: 1280, Wavelet features: 348
# Testing Accuracy: 78.97%, Epochs: 26
